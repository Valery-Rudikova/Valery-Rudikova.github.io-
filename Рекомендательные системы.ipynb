# %% [markdown]
# # <div class="alert alert-block alert-info">Работа с рекомендательными системами

# %% [markdown]
# ## <div class="alert alert-block alert-success">Цель исследования: сформировать вопросы и ответы на основе матрицы предпочтений.

# %%
# импортируем необходимые библиотеки
import pandas as pd
import numpy as np
from itertools import combinations
import seaborn as sns
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ## <a class="anchor" id="1"><div class="alert alert-block alert-success">Предобработка данных

# %%
# загрузим данные
user_item_matrix = pd.read_excel('ratingNames.xlsx')
user_item_matrix
# Out:
#               название фильма  Алексей  Алена  Алина  Альбина  Анастасия  \
# 0             «Дэдпул» (2016)        8      7      0        0          0
# 1       «Бумажный дом» (2019)        7      0      0        0          0
# 2      «Голодные игры» (2012)        6      5      0        7          0
# 3   «Стражи Галактики» (2014)        9      8      0        0          0
# 4       «Интерстеллар» (2014)       10     10      0       10          0
# ..                        ...      ...    ...    ...      ...        ...
# 88                Харли Квинн        0      0      0        0          0
# 89               Слабый герой        0      0      0        0          0
# 90                  Мошенники        0      0      0        0          0
# 91                    Укрытие        0      0      0        0          0
# 92               Дети перемен        0      0      0        0          0
#
#     Ангелина  Андрей  Анна  Арина  ...  Кристина  Майя  Максим  Надежда  \
# 0         10       0     8      0  ...        10    10      10        0
# 1         10      10    10      0  ...        10    10      10        0
# 2         10      10     7      0  ...         0    10      10        0
# 3          7       0    10      0  ...        10    10      10        0
# 4         10       6    10      0  ...         0    10      10        0
# ..       ...     ...   ...    ...  ...       ...   ...     ...      ...
# 88         0       0     0      0  ...         0     0       0        0
# 89         0       0     0      0  ...        10     0       0        0
# 90         0       0     0      0  ...        10     0       0        0
# 91         0       0     0      0  ...        10     0       0        0
# 92         0       0     0      0  ...        10     0       0        0
#
#     Полина  Самира  София  Ульяна  Юлия  Юрий
# 0        7       0      0      10     0     7
# 1        0       0      0       7    10     7
# 2       10       0      0       8     0     8
# 3       10       0      0      10     0    10
# 4       10       0      0      10    10    10
# ..     ...     ...    ...     ...   ...   ...
# 88       0       0      0       8     0     8
# 89       0       0      0       0     0     0
# 90       0       0      0       0     0     0
# 91       0       0      0       0     0     0
# 92       0       0      0       0     0     0
#
# [93 rows x 31 columns]

# %% [markdown]
# Дана матрица предпочтений, в которой 93 строки (фильма) и 31 колонка (пользователи)

# %%
# просматриваем информацию
user_item_matrix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   название фильма  93 non-null     object
#  1   Алексей          93 non-null     int64
#  2   Алена            93 non-null     int64
#  3   Алина            93 non-null     int64
#  4   Альбина          93 non-null     int64
#  5   Анастасия        93 non-null     int64
#  6   Ангелина         93 non-null     int64
#  7   Андрей           93 non-null     int64
#  8   Анна             93 non-null     int64
#  9   Арина            93 non-null     int64
#  10  Артём            93 non-null     int64
#  11  Валерия          93 non-null     int64
#  12  Виктория         93 non-null     int64
#  13  Всеволод         93 non-null     int64
#  14  Георгий          93 non-null     int64
#  15  Дарья            93 non-null     int64
#  16  Дмитрий          93 non-null     int64
#  17  Екатерина        93 non-null     int64
#  18  Елизавета        93 non-null     int64
#  19  Игнат            93 non-null     int64
#  20  Ирина            93 non-null     int64
#  21  Кристина         93 non-null     int64
#  22  Майя             93 non-null     int64
#  23  Максим           93 non-null     int64
#  24  Надежда          93 non-null     int64
#  25  Полина           93 non-null     int64
#  26  Самира           93 non-null     int64
#  27  София            93 non-null     int64
#  28  Ульяна           93 non-null     int64
#  29  Юлия             93 non-null     int64
#  30  Юрий             93 non-null     int64
# dtypes: int64(30), object(1)
# memory usage: 22.6+ KB

# %%
# проверим пропуски
user_item_matrix.isnull().sum()
# Out:
# название фильма    0
# Алексей            0
# Алена              0
# Алина              0
# Альбина            0
# Анастасия          0
# Ангелина           0
# Андрей             0
# Анна               0
# Арина              0
# Артём              0
# Валерия            0
# Виктория           0
# Всеволод           0
# Георгий            0
# Дарья              0
# Дмитрий            0
# Екатерина          0
# Елизавета          0
# Игнат              0
# Ирина              0
# Кристина           0
# Майя               0
# Максим             0
# Надежда            0
# Полина             0
# Самира             0
# София              0
# Ульяна             0
# Юлия               0
# Юрий               0
# dtype: int64

# %%
# проверим дубликаты
user_item_matrix.duplicated().sum()
# Out:
# 0

# %% [markdown]
# На всякий случай были проверены типы данных, пропуски и дубликаты, с этим оказалось все в порядке.

# %% [markdown]
# В матрице виднеются нули, есть два варианта развития событий: либо это 0 как оценки пользователей, либо это пропуски, которые на нули были заменены. Так как у нас нет никакой информации об этом, пока принимаем эти 0 за оценки пользователей и не трогаем матрицу.

# %% [markdown]
# Перейдем к вопросам по матрице предпочтений.

# %% [markdown]
# ## <a class="anchor" id="2"><div class="alert alert-block alert-success">Вопрос 1: пересекаются ли 5-ТОР фильмов пользователей Ангелина и пользователя, самого близкого к ней?

# %%
user_item_matrix = user_item_matrix.set_index('название фильма')
user_item_matrix
# Out:
#                            Алексей  Алена  Алина  Альбина  Анастасия  \
# название фильма
# «Дэдпул» (2016)                  8      7      0        0          0
# «Бумажный дом» (2019)            7      0      0        0          0
# «Голодные игры» (2012)           6      5      0        7          0
# «Стражи Галактики» (2014)        9      8      0        0          0
# «Интерстеллар» (2014)           10     10      0       10          0
# ...                            ...    ...    ...      ...        ...
# Харли Квинн                      0      0      0        0          0
# Слабый герой                     0      0      0        0          0
# Мошенники                        0      0      0        0          0
# Укрытие                          0      0      0        0          0
# Дети перемен                     0      0      0        0          0
#
#                            Ангелина  Андрей  Анна  Арина  Артём  ...  \
# название фильма                                                  ...
# «Дэдпул» (2016)                  10       0     8      0      6  ...
# «Бумажный дом» (2019)            10      10    10      0      8  ...
# «Голодные игры» (2012)           10      10     7      0      3  ...
# «Стражи Галактики» (2014)         7       0    10      0      5  ...
# «Интерстеллар» (2014)            10       6    10      0      5  ...
# ...                             ...     ...   ...    ...    ...  ...
# Харли Квинн                       0       0     0      0      0  ...
# Слабый герой                      0       0     0      0      0  ...
# Мошенники                         0       0     0      0      9  ...
# Укрытие                           0       0     0      0      0  ...
# Дети перемен                      0       0     0      0      0  ...
#
#                            Кристина  Майя  Максим  Надежда  Полина  Самира  \
# название фильма
# «Дэдпул» (2016)                  10    10      10        0       7       0
# «Бумажный дом» (2019)            10    10      10        0       0       0
# «Голодные игры» (2012)            0    10      10        0      10       0
# «Стражи Галактики» (2014)        10    10      10        0      10       0
# «Интерстеллар» (2014)             0    10      10        0      10       0
# ...                             ...   ...     ...      ...     ...     ...
# Харли Квинн                       0     0       0        0       0       0
# Слабый герой                     10     0       0        0       0       0
# Мошенники                        10     0       0        0       0       0
# Укрытие                          10     0       0        0       0       0
# Дети перемен                     10     0       0        0       0       0
#
#                            София  Ульяна  Юлия  Юрий
# название фильма
# «Дэдпул» (2016)                0      10     0     7
# «Бумажный дом» (2019)          0       7    10     7
# «Голодные игры» (2012)         0       8     0     8
# «Стражи Галактики» (2014)      0      10     0    10
# «Интерстеллар» (2014)          0      10    10    10
# ...                          ...     ...   ...   ...
# Харли Квинн                    0       8     0     8
# Слабый герой                   0       0     0     0
# Мошенники                      0       0     0     0
# Укрытие                        0       0     0     0
# Дети перемен                   0       0     0     0
#
# [93 rows x 30 columns]

# %%
filtered_matrix1 = user_item_matrix.T
filtered_matrix1
# Out:
# название фильма  «Дэдпул» (2016)  «Бумажный дом» (2019)  \
# Алексей                        8                      7
# Алена                          7                      0
# Алина                          0                      0
# Альбина                        0                      0
# Анастасия                      0                      0
# Ангелина                      10                     10
# Андрей                         0                     10
# Анна                           8                     10
# Арина                          0                      0
# Артём                          6                      8
# Валерия                        8                      7
# Виктория                       0                      0
# Всеволод                       0                      0
# Георгий                        0                      0
# Дарья                          0                      0
# Дмитрий                       10                     10
# Екатерина                      0                      0
# Елизавета                     10                     10
# Игнат                         10                     10
# Ирина                          0                     10
# Кристина                      10                     10
# Майя                          10                     10
# Максим                        10                     10
# Надежда                        0                      0
# Полина                         7                      0
# Самира                         0                      0
# София                          0                      0
# Ульяна                        10                      7
# Юлия                           0                     10
# Юрий                           7                      7
#
# название фильма  «Голодные игры» (2012)  «Стражи Галактики» (2014)  \
# Алексей                               6                          9
# Алена                                 5                          8
# Алина                                 0                          0
# Альбина                               7                          0
# Анастасия                             0                          0
# Ангелина                             10                          7
# Андрей                               10                          0
# Анна                                  7                         10
# Арина                                 0                          0
# Артём                                 3                          5
# Валерия                               8                          7
# Виктория                              0                          0
# Всеволод                              7                          0
# Георгий                               5                          5
# Дарья                                 0                          0
# Дмитрий                              10                         10
# Екатерина                             0                          0
# Елизавета                            10                         10
# Игнат                                10                         10
# Ирина                                10                          0
# Кристина                              0                         10
# Майя                                 10                         10
# Максим                               10                         10
# Надежда                               0                          0
# Полина                               10                         10
# Самира                                0                          0
# София                                 0                          0
# Ульяна                                8                         10
# Юлия                                  0                          0
# Юрий                                  8                         10
#
# название фильма  «Интерстеллар» (2014)  «Социальная сеть» (2010)  \
# Алексей                             10                         9
# Алена                               10                         0
# Алина                                0                         0
# Альбина                             10                         0
# Анастасия                            0                         0
# Ангелина                            10                         0
# Андрей                               6                         0
# Анна                                10                        10
# Арина                                0                         0
# Артём                                5                         0
# Валерия                             10                         4
# Виктория                             0                         0
# Всеволод                            10                        10
# Георгий                             10                         0
# Дарья                                0                         0
# Дмитрий                             10                        10
# Екатерина                            0                         0
# Елизавета                           10                        10
# Игнат                               10                        10
# Ирина                                0                         0
# Кристина                             0                         0
# Майя                                10                        10
# Максим                              10                         9
# Надежда                              0                         0
# Полина                              10                         0
# Самира                               0                         0
# София                                0                         0
# Ульяна                              10                         0
# Юлия                                10                         0
# Юрий                                10                         0
#
# название фильма  «Человек-паук: Через вселенные» (2018)  «Матрица» (1999)  \
# Алексей                                               7                10
# Алена                                                 0                10
# Алина                                                 0                 0
# Альбина                                               8                 0
# Анастасия                                             0                 0
# Ангелина                                             10                10
# Андрей                                                0                 7
# Анна                                                 10                10
# Арина                                                 0                 0
# Артём                                                 0                 9
# Валерия                                               3                10
# Виктория                                              0                 0
# Всеволод                                              7                10
# Георгий                                               0                 8
# Дарья                                                 0                 0
# Дмитрий                                               7                 7
# Екатерина                                             0                 0
# Елизавета                                            10                10
# Игнат                                                 7                 7
# Ирина                                                 0                 0
# Кристина                                              0                10
# Майя                                                  7                 7
# Максим                                                0                 8
# Надежда                                               0                 0
# Полина                                                0                 0
# Самира                                                0                 0
# София                                                 0                 0
# Ульяна                                                8                10
# Юлия                                                  0                10
# Юрий                                                  8                10
#
# название фильма  «Матрица. Воскрешение» (2021)  \
# Алексей                                     10
# Алена                                        0
# Алина                                        0
# Альбина                                      0
# Анастасия                                    0
# Ангелина                                    10
# Андрей                                       0
# Анна                                         0
# Арина                                        0
# Артём                                        9
# Валерия                                      8
# Виктория                                     0
# Всеволод                                     0
# Георгий                                      0
# Дарья                                        0
# Дмитрий                                      5
# Екатерина                                    0
# Елизавета                                   10
# Игнат                                        5
# Ирина                                        0
# Кристина                                    10
# Майя                                         5
# Максим                                       8
# Надежда                                      0
# Полина                                       0
# Самира                                       0
# София                                        0
# Ульяна                                       9
# Юлия                                         9
# Юрий                                         9
#
# название фильма  «Матрица: Перезагрузка» (2003)  ...  Игра в кальмара  \
# Алексей                                      10  ...                8
# Алена                                         0  ...                7
# Алина                                         0  ...                0
# Альбина                                       0  ...                0
# Анастасия                                     0  ...                0
# Ангелина                                     10  ...                8
# Андрей                                        0  ...                8
# Анна                                          0  ...                9
# Арина                                         0  ...                0
# Артём                                         9  ...                0
# Валерия                                       8  ...                8
# Виктория                                      0  ...                0
# Всеволод                                      0  ...                0
# Георгий                                       0  ...                0
# Дарья                                         0  ...                0
# Дмитрий                                       5  ...                8
# Екатерина                                     0  ...                0
# Елизавета                                    10  ...                0
# Игнат                                         5  ...                1
# Ирина                                         0  ...                0
# Кристина                                     10  ...               10
# Майя                                          5  ...               10
# Максим                                        8  ...                0
# Надежда                                       0  ...                0
# Полина                                        0  ...                7
# Самира                                        0  ...                0
# София                                         0  ...                0
# Ульяна                                        9  ...                8
# Юлия                                          8  ...                0
# Юрий                                          9  ...                8
#
# название фильма  Черное зеркало  Злой город  Одни из нас  \
# Алексей                       0           0            0
# Алена                         0           0            0
# Алина                         0           0            0
# Альбина                       0           0            0
# Анастасия                     0           0            0
# Ангелина                      0           0            0
# Андрей                        0           0            0
# Анна                         10           0            0
# Арина                         0           0            0
# Артём                         0           0            0
# Валерия                       0           0            0
# Виктория                      0           0            0
# Всеволод                     10           0            0
# Георгий                       6           0            0
# Дарья                         0           0            0
# Дмитрий                       0           0            8
# Екатерина                     0           0            0
# Елизавета                    10           0            0
# Игнат                         1           1            1
# Ирина                         0           0            0
# Кристина                     10          10            0
# Майя                          0           0            0
# Максим                        0           0            0
# Надежда                       0           0            0
# Полина                        8           0            6
# Самира                        0           0            0
# София                         0           0            0
# Ульяна                        0           0            0
# Юлия                          8           0            0
# Юрий                          0           0            0
#
# название фильма  Формула преступления  Харли Квинн  Слабый герой  Мошенники  \
# Алексей                             0            0             0          0
# Алена                               0            0             0          0
# Алина                               0            0             0          0
# Альбина                             0            0             0          0
# Анастасия                           0            0             0          0
# Ангелина                            0            0             0          0
# Андрей                              0            0             0          0
# Анна                                0            0             0          0
# Арина                               0            0             0          0
# Артём                               0            0             0          9
# Валерия                             0            0             0          0
# Виктория                            0            0             0          0
# Всеволод                            0            0             0          0
# Георгий                             0            0             0          0
# Дарья                               0            0             0          0
# Дмитрий                             0            0             0          0
# Екатерина                           0            0             0          0
# Елизавета                           0            0             0          0
# Игнат                               1            1             1          1
# Ирина                               0            0             0          0
# Кристина                           10            0            10         10
# Майя                                0            0             0          0
# Максим                              0            0             0          0
# Надежда                             0            0             0          0
# Полина                              0            0             0          0
# Самира                              0            0             0          0
# София                               0            0             0          0
# Ульяна                              8            8             0          0
# Юлия                                0            0             0          0
# Юрий                                8            8             0          0
#
# название фильма  Укрытие  Дети перемен
# Алексей                0             0
# Алена                  0             0
# Алина                  0             0
# Альбина                0             0
# Анастасия              0             0
# Ангелина               0             0
# Андрей                 0             0
# Анна                   0             0
# Арина                  0             0
# Артём                  0             0
# Валерия                0             0
# Виктория               0             0
# Всеволод               0             0
# Георгий                0             0
# Дарья                  0             0
# Дмитрий                0             0
# Екатерина              0             0
# Елизавета              0             0
# Игнат                  1             1
# Ирина                  0             0
# Кристина              10            10
# Майя                   0             0
# Максим                 0             0
# Надежда                0             0
# Полина                 0             0
# Самира                 0             0
# София                  0             0
# Ульяна                 0             0
# Юлия                   0             0
# Юрий                   0             0
#
# [30 rows x 93 columns]

# %%
# воспользуемся классом NearestNeighbors для поиска расстояний
knn = NearestNeighbors(metric = 'cosine',
                       algorithm = 'brute',
                       n_neighbors = 20,
                       n_jobs = -1)

# обучим модель
knn.fit(filtered_matrix1)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1, n_neighbors=20)

# %%
# определимся, сколько рекомендаций мы хотим получить
recommendations = 5

# и для какого зрителя
search_word = 'Ангелина'

# %%
# теперь нужно найти индексы и расстояния
# воспользуемся методом kneighbors()
distances, indices = knn.kneighbors(filtered_matrix1.loc[[search_word]], n_neighbors = recommendations + 1)

# Обрабатываем результаты
similar_movies = filtered_matrix1.index[indices.flatten()[1:]]  # Исключаем субъекта рекомендаций
distances = distances.flatten()[1:]

# Создаем DataFrame с результатами
results = pd.DataFrame({
    'Зритель': similar_movies,
    'Расстояние': distances
})
# Добавляем рейтинг (1 - самый близкий)
results['Рейтинг похожести'] = range(1, len(results)+1)

# Сортируем по расстоянию (на всякий случай)
results = results.sort_values('Расстояние')

print(f"Топ-{recommendations} зрителей с интересами, похожими на '{search_word}':\n")
print(results[['Рейтинг похожести', 'Зритель', 'Расстояние']].to_string(index=False))
# Out:
# Топ-5 зрителей с интересами, похожими на 'Ангелина':
#
#  Рейтинг похожести Зритель  Расстояние
#                  1    Юрий    0.221743
#                  2  Ульяна    0.222368
#                  3 Алексей    0.231239
#                  4   Игнат    0.233530
#                  5 Валерия    0.249075

# %% [markdown]
# Получилось, что для пользователя Ангелина самый близкий - Юрий. Посмотрим фильмы для него.

# %%
user_item_matrix = pd.read_excel('ratingNames.xlsx')
user_item_matrix
# Out:
#               название фильма  Алексей  Алена  Алина  Альбина  Анастасия  \
# 0             «Дэдпул» (2016)        8      7      0        0          0
# 1       «Бумажный дом» (2019)        7      0      0        0          0
# 2      «Голодные игры» (2012)        6      5      0        7          0
# 3   «Стражи Галактики» (2014)        9      8      0        0          0
# 4       «Интерстеллар» (2014)       10     10      0       10          0
# ..                        ...      ...    ...    ...      ...        ...
# 88                Харли Квинн        0      0      0        0          0
# 89               Слабый герой        0      0      0        0          0
# 90                  Мошенники        0      0      0        0          0
# 91                    Укрытие        0      0      0        0          0
# 92               Дети перемен        0      0      0        0          0
#
#     Ангелина  Андрей  Анна  Арина  ...  Кристина  Майя  Максим  Надежда  \
# 0         10       0     8      0  ...        10    10      10        0
# 1         10      10    10      0  ...        10    10      10        0
# 2         10      10     7      0  ...         0    10      10        0
# 3          7       0    10      0  ...        10    10      10        0
# 4         10       6    10      0  ...         0    10      10        0
# ..       ...     ...   ...    ...  ...       ...   ...     ...      ...
# 88         0       0     0      0  ...         0     0       0        0
# 89         0       0     0      0  ...        10     0       0        0
# 90         0       0     0      0  ...        10     0       0        0
# 91         0       0     0      0  ...        10     0       0        0
# 92         0       0     0      0  ...        10     0       0        0
#
#     Полина  Самира  София  Ульяна  Юлия  Юрий
# 0        7       0      0      10     0     7
# 1        0       0      0       7    10     7
# 2       10       0      0       8     0     8
# 3       10       0      0      10     0    10
# 4       10       0      0      10    10    10
# ..     ...     ...    ...     ...   ...   ...
# 88       0       0      0       8     0     8
# 89       0       0      0       0     0     0
# 90       0       0      0       0     0     0
# 91       0       0      0       0     0     0
# 92       0       0      0       0     0     0
#
# [93 rows x 31 columns]

# %%
# находим топ-5 фильмов для Юрия с оценками этих фильмов
search_word = 'Юрий'

# %%
a = user_item_matrix.nlargest(5, search_word)[['название фильма', search_word]]
a
# Out:
#               название фильма  Юрий
# 3   «Стражи Галактики» (2014)    10
# 4       «Интерстеллар» (2014)    10
# 7            «Матрица» (1999)    10
# 16          «Аватар 2» (2022)    10
# 17            «Аватар» (2009)    10

# %%
# находим топ-5 фильмов для Ангелины с оценками этих фильмов
search_word = 'Ангелина'

# %%
a = user_item_matrix.nlargest(5, search_word)[['название фильма', search_word]]
a
# Out:
#                           название фильма  Ангелина
# 0                         «Дэдпул» (2016)        10
# 1                   «Бумажный дом» (2019)        10
# 2                  «Голодные игры» (2012)        10
# 4                   «Интерстеллар» (2014)        10
# 6  «Человек-паук: Через вселенные» (2018)        10

# %% [markdown]
# В пересечении тоже Интерстеллар в фильмах топ-5.

# %% [markdown]
# ## <a class="anchor" id="2"><div class="alert alert-block alert-success">Вопрос 2: отличается ли средний рейтинг фильмов у пользователей Игнат и похожего на него?

# %%
user_item_matrix = user_item_matrix.set_index('название фильма')
user_item_matrix
# Out:
#                            Алексей  Алена  Алина  Альбина  Анастасия  \
# название фильма
# «Дэдпул» (2016)                  8      7      0        0          0
# «Бумажный дом» (2019)            7      0      0        0          0
# «Голодные игры» (2012)           6      5      0        7          0
# «Стражи Галактики» (2014)        9      8      0        0          0
# «Интерстеллар» (2014)           10     10      0       10          0
# ...                            ...    ...    ...      ...        ...
# Харли Квинн                      0      0      0        0          0
# Слабый герой                     0      0      0        0          0
# Мошенники                        0      0      0        0          0
# Укрытие                          0      0      0        0          0
# Дети перемен                     0      0      0        0          0
#
#                            Ангелина  Андрей  Анна  Арина  Артём  ...  \
# название фильма                                                  ...
# «Дэдпул» (2016)                  10       0     8      0      6  ...
# «Бумажный дом» (2019)            10      10    10      0      8  ...
# «Голодные игры» (2012)           10      10     7      0      3  ...
# «Стражи Галактики» (2014)         7       0    10      0      5  ...
# «Интерстеллар» (2014)            10       6    10      0      5  ...
# ...                             ...     ...   ...    ...    ...  ...
# Харли Квинн                       0       0     0      0      0  ...
# Слабый герой                      0       0     0      0      0  ...
# Мошенники                         0       0     0      0      9  ...
# Укрытие                           0       0     0      0      0  ...
# Дети перемен                      0       0     0      0      0  ...
#
#                            Кристина  Майя  Максим  Надежда  Полина  Самира  \
# название фильма
# «Дэдпул» (2016)                  10    10      10        0       7       0
# «Бумажный дом» (2019)            10    10      10        0       0       0
# «Голодные игры» (2012)            0    10      10        0      10       0
# «Стражи Галактики» (2014)        10    10      10        0      10       0
# «Интерстеллар» (2014)             0    10      10        0      10       0
# ...                             ...   ...     ...      ...     ...     ...
# Харли Квинн                       0     0       0        0       0       0
# Слабый герой                     10     0       0        0       0       0
# Мошенники                        10     0       0        0       0       0
# Укрытие                          10     0       0        0       0       0
# Дети перемен                     10     0       0        0       0       0
#
#                            София  Ульяна  Юлия  Юрий
# название фильма
# «Дэдпул» (2016)                0      10     0     7
# «Бумажный дом» (2019)          0       7    10     7
# «Голодные игры» (2012)         0       8     0     8
# «Стражи Галактики» (2014)      0      10     0    10
# «Интерстеллар» (2014)          0      10    10    10
# ...                          ...     ...   ...   ...
# Харли Квинн                    0       8     0     8
# Слабый герой                   0       0     0     0
# Мошенники                      0       0     0     0
# Укрытие                        0       0     0     0
# Дети перемен                   0       0     0     0
#
# [93 rows x 30 columns]

# %%
filtered_matrix1 = user_item_matrix.T
filtered_matrix1
# Out:
# название фильма  «Дэдпул» (2016)  «Бумажный дом» (2019)  \
# Алексей                        8                      7
# Алена                          7                      0
# Алина                          0                      0
# Альбина                        0                      0
# Анастасия                      0                      0
# Ангелина                      10                     10
# Андрей                         0                     10
# Анна                           8                     10
# Арина                          0                      0
# Артём                          6                      8
# Валерия                        8                      7
# Виктория                       0                      0
# Всеволод                       0                      0
# Георгий                        0                      0
# Дарья                          0                      0
# Дмитрий                       10                     10
# Екатерина                      0                      0
# Елизавета                     10                     10
# Игнат                         10                     10
# Ирина                          0                     10
# Кристина                      10                     10
# Майя                          10                     10
# Максим                        10                     10
# Надежда                        0                      0
# Полина                         7                      0
# Самира                         0                      0
# София                          0                      0
# Ульяна                        10                      7
# Юлия                           0                     10
# Юрий                           7                      7
#
# название фильма  «Голодные игры» (2012)  «Стражи Галактики» (2014)  \
# Алексей                               6                          9
# Алена                                 5                          8
# Алина                                 0                          0
# Альбина                               7                          0
# Анастасия                             0                          0
# Ангелина                             10                          7
# Андрей                               10                          0
# Анна                                  7                         10
# Арина                                 0                          0
# Артём                                 3                          5
# Валерия                               8                          7
# Виктория                              0                          0
# Всеволод                              7                          0
# Георгий                               5                          5
# Дарья                                 0                          0
# Дмитрий                              10                         10
# Екатерина                             0                          0
# Елизавета                            10                         10
# Игнат                                10                         10
# Ирина                                10                          0
# Кристина                              0                         10
# Майя                                 10                         10
# Максим                               10                         10
# Надежда                               0                          0
# Полина                               10                         10
# Самира                                0                          0
# София                                 0                          0
# Ульяна                                8                         10
# Юлия                                  0                          0
# Юрий                                  8                         10
#
# название фильма  «Интерстеллар» (2014)  «Социальная сеть» (2010)  \
# Алексей                             10                         9
# Алена                               10                         0
# Алина                                0                         0
# Альбина                             10                         0
# Анастасия                            0                         0
# Ангелина                            10                         0
# Андрей                               6                         0
# Анна                                10                        10
# Арина                                0                         0
# Артём                                5                         0
# Валерия                             10                         4
# Виктория                             0                         0
# Всеволод                            10                        10
# Георгий                             10                         0
# Дарья                                0                         0
# Дмитрий                             10                        10
# Екатерина                            0                         0
# Елизавета                           10                        10
# Игнат                               10                        10
# Ирина                                0                         0
# Кристина                             0                         0
# Майя                                10                        10
# Максим                              10                         9
# Надежда                              0                         0
# Полина                              10                         0
# Самира                               0                         0
# София                                0                         0
# Ульяна                              10                         0
# Юлия                                10                         0
# Юрий                                10                         0
#
# название фильма  «Человек-паук: Через вселенные» (2018)  «Матрица» (1999)  \
# Алексей                                               7                10
# Алена                                                 0                10
# Алина                                                 0                 0
# Альбина                                               8                 0
# Анастасия                                             0                 0
# Ангелина                                             10                10
# Андрей                                                0                 7
# Анна                                                 10                10
# Арина                                                 0                 0
# Артём                                                 0                 9
# Валерия                                               3                10
# Виктория                                              0                 0
# Всеволод                                              7                10
# Георгий                                               0                 8
# Дарья                                                 0                 0
# Дмитрий                                               7                 7
# Екатерина                                             0                 0
# Елизавета                                            10                10
# Игнат                                                 7                 7
# Ирина                                                 0                 0
# Кристина                                              0                10
# Майя                                                  7                 7
# Максим                                                0                 8
# Надежда                                               0                 0
# Полина                                                0                 0
# Самира                                                0                 0
# София                                                 0                 0
# Ульяна                                                8                10
# Юлия                                                  0                10
# Юрий                                                  8                10
#
# название фильма  «Матрица. Воскрешение» (2021)  \
# Алексей                                     10
# Алена                                        0
# Алина                                        0
# Альбина                                      0
# Анастасия                                    0
# Ангелина                                    10
# Андрей                                       0
# Анна                                         0
# Арина                                        0
# Артём                                        9
# Валерия                                      8
# Виктория                                     0
# Всеволод                                     0
# Георгий                                      0
# Дарья                                        0
# Дмитрий                                      5
# Екатерина                                    0
# Елизавета                                   10
# Игнат                                        5
# Ирина                                        0
# Кристина                                    10
# Майя                                         5
# Максим                                       8
# Надежда                                      0
# Полина                                       0
# Самира                                       0
# София                                        0
# Ульяна                                       9
# Юлия                                         9
# Юрий                                         9
#
# название фильма  «Матрица: Перезагрузка» (2003)  ...  Игра в кальмара  \
# Алексей                                      10  ...                8
# Алена                                         0  ...                7
# Алина                                         0  ...                0
# Альбина                                       0  ...                0
# Анастасия                                     0  ...                0
# Ангелина                                     10  ...                8
# Андрей                                        0  ...                8
# Анна                                          0  ...                9
# Арина                                         0  ...                0
# Артём                                         9  ...                0
# Валерия                                       8  ...                8
# Виктория                                      0  ...                0
# Всеволод                                      0  ...                0
# Георгий                                       0  ...                0
# Дарья                                         0  ...                0
# Дмитрий                                       5  ...                8
# Екатерина                                     0  ...                0
# Елизавета                                    10  ...                0
# Игнат                                         5  ...                1
# Ирина                                         0  ...                0
# Кристина                                     10  ...               10
# Майя                                          5  ...               10
# Максим                                        8  ...                0
# Надежда                                       0  ...                0
# Полина                                        0  ...                7
# Самира                                        0  ...                0
# София                                         0  ...                0
# Ульяна                                        9  ...                8
# Юлия                                          8  ...                0
# Юрий                                          9  ...                8
#
# название фильма  Черное зеркало  Злой город  Одни из нас  \
# Алексей                       0           0            0
# Алена                         0           0            0
# Алина                         0           0            0
# Альбина                       0           0            0
# Анастасия                     0           0            0
# Ангелина                      0           0            0
# Андрей                        0           0            0
# Анна                         10           0            0
# Арина                         0           0            0
# Артём                         0           0            0
# Валерия                       0           0            0
# Виктория                      0           0            0
# Всеволод                     10           0            0
# Георгий                       6           0            0
# Дарья                         0           0            0
# Дмитрий                       0           0            8
# Екатерина                     0           0            0
# Елизавета                    10           0            0
# Игнат                         1           1            1
# Ирина                         0           0            0
# Кристина                     10          10            0
# Майя                          0           0            0
# Максим                        0           0            0
# Надежда                       0           0            0
# Полина                        8           0            6
# Самира                        0           0            0
# София                         0           0            0
# Ульяна                        0           0            0
# Юлия                          8           0            0
# Юрий                          0           0            0
#
# название фильма  Формула преступления  Харли Квинн  Слабый герой  Мошенники  \
# Алексей                             0            0             0          0
# Алена                               0            0             0          0
# Алина                               0            0             0          0
# Альбина                             0            0             0          0
# Анастасия                           0            0             0          0
# Ангелина                            0            0             0          0
# Андрей                              0            0             0          0
# Анна                                0            0             0          0
# Арина                               0            0             0          0
# Артём                               0            0             0          9
# Валерия                             0            0             0          0
# Виктория                            0            0             0          0
# Всеволод                            0            0             0          0
# Георгий                             0            0             0          0
# Дарья                               0            0             0          0
# Дмитрий                             0            0             0          0
# Екатерина                           0            0             0          0
# Елизавета                           0            0             0          0
# Игнат                               1            1             1          1
# Ирина                               0            0             0          0
# Кристина                           10            0            10         10
# Майя                                0            0             0          0
# Максим                              0            0             0          0
# Надежда                             0            0             0          0
# Полина                              0            0             0          0
# Самира                              0            0             0          0
# София                               0            0             0          0
# Ульяна                              8            8             0          0
# Юлия                                0            0             0          0
# Юрий                                8            8             0          0
#
# название фильма  Укрытие  Дети перемен
# Алексей                0             0
# Алена                  0             0
# Алина                  0             0
# Альбина                0             0
# Анастасия              0             0
# Ангелина               0             0
# Андрей                 0             0
# Анна                   0             0
# Арина                  0             0
# Артём                  0             0
# Валерия                0             0
# Виктория               0             0
# Всеволод               0             0
# Георгий                0             0
# Дарья                  0             0
# Дмитрий                0             0
# Екатерина              0             0
# Елизавета              0             0
# Игнат                  1             1
# Ирина                  0             0
# Кристина              10            10
# Майя                   0             0
# Максим                 0             0
# Надежда                0             0
# Полина                 0             0
# Самира                 0             0
# София                  0             0
# Ульяна                 0             0
# Юлия                   0             0
# Юрий                   0             0
#
# [30 rows x 93 columns]

# %%
# воспользуемся классом NearestNeighbors для поиска расстояний
knn = NearestNeighbors(metric = 'cosine',
                       algorithm = 'brute',
                       n_neighbors = 20,
                       n_jobs = -1)

# обучим модель
knn.fit(filtered_matrix1)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1, n_neighbors=20)

# %%
# определимся, сколько рекомендаций мы хотим получить
recommendations = 5

# и для какого зрителя
search_word = 'Игнат'

# %%
# теперь нужно найти индексы и расстояния
# воспользуемся методом kneighbors()
distances, indices = knn.kneighbors(filtered_matrix1.loc[[search_word]], n_neighbors = recommendations + 1)

# Обрабатываем результаты
similar_movies = filtered_matrix1.index[indices.flatten()[1:]]  # Исключаем субъекта рекомендаций
distances = distances.flatten()[1:]

# Создаем DataFrame с результатами
results = pd.DataFrame({
    'Зритель': similar_movies,
    'Расстояние': distances
})
# Добавляем рейтинг (1 - самый близкий)
results['Рейтинг похожести'] = range(1, len(results)+1)

# Сортируем по расстоянию (на всякий случай)
results = results.sort_values('Расстояние')

print(f"Топ-{recommendations} зрителей с интересами, похожими на '{search_word}':\n")
print(results[['Рейтинг похожести', 'Зритель', 'Расстояние']].to_string(index=False))
# Out:
# Топ-5 зрителей с интересами, похожими на 'Игнат':
#
#  Рейтинг похожести  Зритель  Расстояние
#                  1     Майя    0.046095
#                  2  Дмитрий    0.075094
#                  3   Ульяна    0.230282
#                  4 Ангелина    0.233530
#                  5     Юрий    0.233748

# %% [markdown]
# Майя и Игнат близки по интересам, посмотрим их средний рейтинг фильмов

# %%
user_ratings = user_item_matrix['Игнат']
print(f"  • Средний рейтинг Игната: {user_ratings.mean():.1f}")
# Out:
#   • Средний рейтинг Игната: 3.2

# %%
user_ratings = user_item_matrix['Майя']
print(f"  • Средний рейтинг Майи: {user_ratings.mean():.1f}")
# Out:
#   • Средний рейтинг Майи: 3.1

# %% [markdown]
# В итоге их средние рейтинги очень близки, отличаются на 0.1.

# %% [markdown]
# ## <a class="anchor" id="2"><div class="alert alert-block alert-success">Вопрос 3: отличается ли количество оценок у пользователей Юлия и похожего на него?

# %%
# воспользуемся классом NearestNeighbors для поиска расстояний
knn = NearestNeighbors(metric = 'cosine',
                       algorithm = 'brute',
                       n_neighbors = 20,
                       n_jobs = -1)

# обучим модель
knn.fit(filtered_matrix1)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1, n_neighbors=20)

# %%
# определимся, сколько рекомендаций мы хотим получить
recommendations = 5

# и для какого зрителя
search_word = 'Юлия'

# %%
# теперь нужно найти индексы и расстояния
# воспользуемся методом kneighbors()
distances, indices = knn.kneighbors(filtered_matrix1.loc[[search_word]], n_neighbors = recommendations + 1)

# Обрабатываем результаты
similar_movies = filtered_matrix1.index[indices.flatten()[1:]]  # Исключаем субъекта рекомендаций
distances = distances.flatten()[1:]

# Создаем DataFrame с результатами
results = pd.DataFrame({
    'Зритель': similar_movies,
    'Расстояние': distances
})
# Добавляем рейтинг (1 - самый близкий)
results['Рейтинг похожести'] = range(1, len(results)+1)

# Сортируем по расстоянию (на всякий случай)
results = results.sort_values('Расстояние')

print(f"Топ-{recommendations} зрителей с интересами, похожими на '{search_word}':\n")
print(results[['Рейтинг похожести', 'Зритель', 'Расстояние']].to_string(index=False))
# Out:
# Топ-5 зрителей с интересами, похожими на 'Юлия':
#
#  Рейтинг похожести Зритель  Расстояние
#                  1  Полина    0.363025
#                  2 Алексей    0.365190
#                  3    Юрий    0.375473
#                  4  Ульяна    0.382730
#                  5   Артём    0.388475

# %% [markdown]
# Юлия и Полина близки по интересам, посмотрим их средний рейтинг фильмов

# %%
user_ratings = user_item_matrix['Игнат']
print(f"  • Оценила фильмов Юлия: {len(user_ratings)}")
# Out:
#   • Оценила фильмов Юлия: 93

# %%
user_ratings = user_item_matrix['Полина']
print(f"  • Оценил фильмов Полина: {len(user_ratings)}")
# Out:
#   • Оценил фильмов Полина: 93

# %% [markdown]
# Они оценили одинаковое количество фильмов.

# %% [markdown]
# ## <a class="anchor" id="2"><div class="alert alert-block alert-success">Вопрос 4: отличается ли средний рейтинг фильма «Дэдпул» (2016) и самого похожего на него?

# %%
filtered_matrix = user_item_matrix

# %%
# воспользуемся классом NearestNeighbors для поиска расстояний
knn = NearestNeighbors(metric = 'cosine',
                       algorithm = 'brute',
                       n_neighbors = 5,
                       n_jobs = -1)

# обучим модель
knn.fit(filtered_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1)

# %%
# определимся, сколько рекомендаций мы хотим получить
recommendations = 5

# и на основе какого фильма
search_word = '«Дэдпул» (2016)'

# %%
# теперь нужно найти индексы и расстояния фильмов, которые похожи на наш запрос
# воспользуемся методом kneighbors()
distances, indices = knn.kneighbors(filtered_matrix.loc[[search_word]], n_neighbors = recommendations + 1)

# %%
indices
# Out:
# array([[ 0,  3, 36, 10,  9, 22]], dtype=int64)

# %%
distances
# Out:
# array([[0.        , 0.02319406, 0.10012523, 0.14147297, 0.1480065 ,
#         0.15033642]])

# %%
# Обрабатываем результаты
similar_movies = filtered_matrix.index[indices.flatten()[1:]]  # Исключаем исходный фильм
distances = distances.flatten()[1:]

# Создаем DataFrame с результатами
results = pd.DataFrame({
    'Фильм': similar_movies,
    'Расстояние': distances
})
# Добавляем рейтинг (1 - самый близкий)
results['Рейтинг похожести'] = range(1, len(results)+1)

# Сортируем по расстоянию (на всякий случай)
results = results.sort_values('Расстояние')

print(f"Топ-{recommendations} похожих фильмов на '{search_word}':\n")
print(results[['Рейтинг похожести', 'Фильм', 'Расстояние']].to_string(index=False))
# Out:
# Топ-5 похожих фильмов на '«Дэдпул» (2016)':
#
#  Рейтинг похожести                              Фильм  Расстояние
#                  1          «Стражи Галактики» (2014)    0.023194
#                  2 «Стражи Галактики. Часть 2» (2017)    0.100125
#                  3        «Матрица: Революция» (2003)    0.141473
#                  4     «Матрица: Перезагрузка» (2003)    0.148007
#                  5                    «Форсаж» (2001)    0.150336

# %%
# загрузим данные
user_item_matrix = pd.read_excel('ratingNames.xlsx')
user_item_matrix
# Out:
#               название фильма  Алексей  Алена  Алина  Альбина  Анастасия  \
# 0             «Дэдпул» (2016)        8      7      0        0          0
# 1       «Бумажный дом» (2019)        7      0      0        0          0
# 2      «Голодные игры» (2012)        6      5      0        7          0
# 3   «Стражи Галактики» (2014)        9      8      0        0          0
# 4       «Интерстеллар» (2014)       10     10      0       10          0
# ..                        ...      ...    ...    ...      ...        ...
# 88                Харли Квинн        0      0      0        0          0
# 89               Слабый герой        0      0      0        0          0
# 90                  Мошенники        0      0      0        0          0
# 91                    Укрытие        0      0      0        0          0
# 92               Дети перемен        0      0      0        0          0
#
#     Ангелина  Андрей  Анна  Арина  ...  Кристина  Майя  Максим  Надежда  \
# 0         10       0     8      0  ...        10    10      10        0
# 1         10      10    10      0  ...        10    10      10        0
# 2         10      10     7      0  ...         0    10      10        0
# 3          7       0    10      0  ...        10    10      10        0
# 4         10       6    10      0  ...         0    10      10        0
# ..       ...     ...   ...    ...  ...       ...   ...     ...      ...
# 88         0       0     0      0  ...         0     0       0        0
# 89         0       0     0      0  ...        10     0       0        0
# 90         0       0     0      0  ...        10     0       0        0
# 91         0       0     0      0  ...        10     0       0        0
# 92         0       0     0      0  ...        10     0       0        0
#
#     Полина  Самира  София  Ульяна  Юлия  Юрий
# 0        7       0      0      10     0     7
# 1        0       0      0       7    10     7
# 2       10       0      0       8     0     8
# 3       10       0      0      10     0    10
# 4       10       0      0      10    10    10
# ..     ...     ...    ...     ...   ...   ...
# 88       0       0      0       8     0     8
# 89       0       0      0       0     0     0
# 90       0       0      0       0     0     0
# 91       0       0      0       0     0     0
# 92       0       0      0       0     0     0
#
# [93 rows x 31 columns]

# %%
film = '«Дэдпул» (2016)'
ratings = user_item_matrix.loc[user_item_matrix['название фильма'] == film, users].values[0]
non_zero_ratings = ratings
non_zero_ratings.mean().round(1)
# Out:
# 4.4

# %%
film = '«Стражи Галактики» (2014)'
ratings = user_item_matrix.loc[user_item_matrix['название фильма'] == film, users].values[0]
non_zero_ratings = ratings
non_zero_ratings.mean().round(1)
# Out:
# 4.7

# %% [markdown]
# У второго фильма оценка получилась даже больше, чем у первого.

# %% [markdown]
# ## <a class="anchor" id="2"><div class="alert alert-block alert-success">Вопрос 5: отличается ли количество оценок фильма Укрытие и самого похожего на него?

# %%
filtered_matrix = user_item_matrix.set_index('название фильма')

# %%
# воспользуемся классом NearestNeighbors для поиска расстояний
knn = NearestNeighbors(metric = 'cosine',
                       algorithm = 'brute',
                       n_neighbors = 5,
                       n_jobs = -1)

# обучим модель
knn.fit(filtered_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1)

# %%
# определимся, сколько рекомендаций мы хотим получить
recommendations = 5

# и на основе какого фильма
search_word = 'Укрытие'

# %%
# теперь нужно найти индексы и расстояния фильмов, которые похожи на наш запрос
# воспользуемся методом kneighbors()
distances, indices = knn.kneighbors(filtered_matrix.loc[[search_word]], n_neighbors = recommendations + 1)

# %%
indices
# Out:
# array([[89, 91, 85, 92, 60, 57]], dtype=int64)

# %%
distances
# Out:
# array([[0.        , 0.        , 0.        , 0.        , 0.00496281,
#         0.00990099]])

# %%
# Обрабатываем результаты
similar_movies = filtered_matrix.index[indices.flatten()[1:]]  # Исключаем исходный фильм
distances = distances.flatten()[1:]

# Создаем DataFrame с результатами
results = pd.DataFrame({
    'Фильм': similar_movies,
    'Расстояние': distances
})
# Добавляем рейтинг (1 - самый близкий)
results['Рейтинг похожести'] = range(1, len(results)+1)

# Сортируем по расстоянию (на всякий случай)
results = results.sort_values('Расстояние')

print(f"Топ-{recommendations} похожих фильмов на '{search_word}':\n")
print(results[['Рейтинг похожести', 'Фильм', 'Расстояние']].to_string(index=False))
# Out:
# Топ-5 похожих фильмов на 'Укрытие':
#
#  Рейтинг похожести                         Фильм  Расстояние
#                  1                       Укрытие    0.000000
#                  2                    Злой город    0.000000
#                  3                  Дети перемен    0.000000
#                  4             «Ячейка общества»    0.004963
#                  5 «Надо снимать фильмы о любви»    0.009901

# %%
# загрузим данные
user_item_matrix = pd.read_excel('ratingNames.xlsx')
user_item_matrix
# Out:
#               название фильма  Алексей  Алена  Алина  Альбина  Анастасия  \
# 0             «Дэдпул» (2016)        8      7      0        0          0
# 1       «Бумажный дом» (2019)        7      0      0        0          0
# 2      «Голодные игры» (2012)        6      5      0        7          0
# 3   «Стражи Галактики» (2014)        9      8      0        0          0
# 4       «Интерстеллар» (2014)       10     10      0       10          0
# ..                        ...      ...    ...    ...      ...        ...
# 88                Харли Квинн        0      0      0        0          0
# 89               Слабый герой        0      0      0        0          0
# 90                  Мошенники        0      0      0        0          0
# 91                    Укрытие        0      0      0        0          0
# 92               Дети перемен        0      0      0        0          0
#
#     Ангелина  Андрей  Анна  Арина  ...  Кристина  Майя  Максим  Надежда  \
# 0         10       0     8      0  ...        10    10      10        0
# 1         10      10    10      0  ...        10    10      10        0
# 2         10      10     7      0  ...         0    10      10        0
# 3          7       0    10      0  ...        10    10      10        0
# 4         10       6    10      0  ...         0    10      10        0
# ..       ...     ...   ...    ...  ...       ...   ...     ...      ...
# 88         0       0     0      0  ...         0     0       0        0
# 89         0       0     0      0  ...        10     0       0        0
# 90         0       0     0      0  ...        10     0       0        0
# 91         0       0     0      0  ...        10     0       0        0
# 92         0       0     0      0  ...        10     0       0        0
#
#     Полина  Самира  София  Ульяна  Юлия  Юрий
# 0        7       0      0      10     0     7
# 1        0       0      0       7    10     7
# 2       10       0      0       8     0     8
# 3       10       0      0      10     0    10
# 4       10       0      0      10    10    10
# ..     ...     ...    ...     ...   ...   ...
# 88       0       0      0       8     0     8
# 89       0       0      0       0     0     0
# 90       0       0      0       0     0     0
# 91       0       0      0       0     0     0
# 92       0       0      0       0     0     0
#
# [93 rows x 31 columns]

# %%
film = 'Укрытие'
ratings = user_item_matrix.loc[user_item_matrix['название фильма'] == film, users].values[0]
non_zero_ratings = ratings
len(non_zero_ratings)
# Out:
# 30

# %%
film = 'Злой город'
ratings = user_item_matrix.loc[user_item_matrix['название фильма'] == film, users].values[0]
non_zero_ratings = ratings
len(non_zero_ratings)
# Out:
# 30

# %% [markdown]
# У этих фильмов одинаковое количество оценок.

# %% [markdown]
# # <div class="alert alert-block alert-info">Дополнительная часть: применим фильтр к матрице предпочтений, чтобы исключить малоактивных пользоваталей и фильмы с малым количеством ненулевых оценок, и ответим на те же самые вопросы.

# %%
# Подсчет количества нулей в каждом столбце (кроме первого)
zero_counts = (user_item_matrix == 0).sum()

# Задаем порог
threshold = 85

# Выбираем столбцы, где нулей не больше порога
columns_to_keep = [col for col in user_item_matrix.columns if zero_counts[col] <= threshold]

# Создаем новый DataFrame без "нулевых" столбцов
user_item_matrix1 = user_item_matrix[columns_to_keep]

# %%
user_item_matrix1.shape #посмотрим сколько пользователей и фильмов осталось
# Out:
# (93, 21)

# %%
filtered_matrix = (
    user_item_matrix1
    .assign(Количество_нулей=lambda x: (x == 0).sum(axis=1))
    .query("Количество_нулей <= 15")
    .drop(columns=['Количество_нулей'])
)
filtered_matrix.shape # посмотрим сколько пользователей и фильмов осталось
# Out:
# (64, 21)

# %%
user_item_matrix = filtered_matrix
user_item_matrix
# Out:
#               название фильма  Алексей  Алена  Альбина  Ангелина  Андрей  \
# 0             «Дэдпул» (2016)        8      7        0        10       0
# 1       «Бумажный дом» (2019)        7      0        0        10      10
# 2      «Голодные игры» (2012)        6      5        7        10      10
# 3   «Стражи Галактики» (2014)        9      8        0         7       0
# 4       «Интерстеллар» (2014)       10     10       10        10       6
# ..                        ...      ...    ...      ...       ...     ...
# 78            "Темный рыцарь"       10      0        0         0       0
# 79            "Люди в черном"       10      9        0         7       7
# 82        Очень странные дела        0      0        0         0       0
# 83            Игра в кальмара        8      7        0         8       8
# 84             Черное зеркало        0      0        0         0       0
#
#     Анна  Артём  Валерия  Всеволод  ...  Дмитрий  Елизавета  Игнат  Кристина  \
# 0      8      6        8         0  ...       10         10     10        10
# 1     10      8        7         0  ...       10         10     10        10
# 2      7      3        8         7  ...       10         10     10         0
# 3     10      5        7         0  ...       10         10     10        10
# 4     10      5       10        10  ...       10         10     10         0
# ..   ...    ...      ...       ...  ...      ...        ...    ...       ...
# 78    10      0        7        10  ...       10          0      1        10
# 79    10     10        9        10  ...       10         10      1        10
# 82    10     10        0        10  ...        0          0      1        10
# 83     9      0        8         0  ...        8          0      1        10
# 84    10      0        0        10  ...        0         10      1        10
#
#     Майя  Максим  Полина  Ульяна  Юлия  Юрий
# 0     10      10       7      10     0     7
# 1     10      10       0       7    10     7
# 2     10      10      10       8     0     8
# 3     10      10      10      10     0    10
# 4     10      10      10      10    10    10
# ..   ...     ...     ...     ...   ...   ...
# 78     0       0      10       0     9     0
# 79     0       0       0      10     0    10
# 82    10      10      10       7    10     7
# 83    10       0       7       8     0     8
# 84     0       0       8       0     8     0
#
# [64 rows x 21 columns]

# %% [markdown]
# ## <a class="anchor" id="2"><div class="alert alert-block alert-success">Вопрос 1: пересекаются ли 5-ТОР фильмов пользователей Ангелина и пользователя, самого близкого к ней?

# %%
user_item_matrix = user_item_matrix.set_index('название фильма')
user_item_matrix
# Out:
#                            Алексей  Алена  Альбина  Ангелина  Андрей  Анна  \
# название фильма
# «Дэдпул» (2016)                  8      7        0        10       0     8
# «Бумажный дом» (2019)            7      0        0        10      10    10
# «Голодные игры» (2012)           6      5        7        10      10     7
# «Стражи Галактики» (2014)        9      8        0         7       0    10
# «Интерстеллар» (2014)           10     10       10        10       6    10
# ...                            ...    ...      ...       ...     ...   ...
# "Темный рыцарь"                 10      0        0         0       0    10
# "Люди в черном"                 10      9        0         7       7    10
# Очень странные дела              0      0        0         0       0    10
# Игра в кальмара                  8      7        0         8       8     9
# Черное зеркало                   0      0        0         0       0    10
#
#                            Артём  Валерия  Всеволод  Георгий  Дмитрий  \
# название фильма
# «Дэдпул» (2016)                6        8         0        0       10
# «Бумажный дом» (2019)          8        7         0        0       10
# «Голодные игры» (2012)         3        8         7        5       10
# «Стражи Галактики» (2014)      5        7         0        5       10
# «Интерстеллар» (2014)          5       10        10       10       10
# ...                          ...      ...       ...      ...      ...
# "Темный рыцарь"                0        7        10        0       10
# "Люди в черном"               10        9        10        0       10
# Очень странные дела           10        0        10        6        0
# Игра в кальмара                0        8         0        0        8
# Черное зеркало                 0        0        10        6        0
#
#                            Елизавета  Игнат  Кристина  Майя  Максим  Полина  \
# название фильма
# «Дэдпул» (2016)                   10     10        10    10      10       7
# «Бумажный дом» (2019)             10     10        10    10      10       0
# «Голодные игры» (2012)            10     10         0    10      10      10
# «Стражи Галактики» (2014)         10     10        10    10      10      10
# «Интерстеллар» (2014)             10     10         0    10      10      10
# ...                              ...    ...       ...   ...     ...     ...
# "Темный рыцарь"                    0      1        10     0       0      10
# "Люди в черном"                   10      1        10     0       0       0
# Очень странные дела                0      1        10    10      10      10
# Игра в кальмара                    0      1        10    10       0       7
# Черное зеркало                    10      1        10     0       0       8
#
#                            Ульяна  Юлия  Юрий
# название фильма
# «Дэдпул» (2016)                10     0     7
# «Бумажный дом» (2019)           7    10     7
# «Голодные игры» (2012)          8     0     8
# «Стражи Галактики» (2014)      10     0    10
# «Интерстеллар» (2014)          10    10    10
# ...                           ...   ...   ...
# "Темный рыцарь"                 0     9     0
# "Люди в черном"                10     0    10
# Очень странные дела             7    10     7
# Игра в кальмара                 8     0     8
# Черное зеркало                  0     8     0
#
# [64 rows x 20 columns]

# %%
filtered_matrix1 = user_item_matrix.T
filtered_matrix1
# Out:
# название фильма  «Дэдпул» (2016)  «Бумажный дом» (2019)  \
# Алексей                        8                      7
# Алена                          7                      0
# Альбина                        0                      0
# Ангелина                      10                     10
# Андрей                         0                     10
# Анна                           8                     10
# Артём                          6                      8
# Валерия                        8                      7
# Всеволод                       0                      0
# Георгий                        0                      0
# Дмитрий                       10                     10
# Елизавета                     10                     10
# Игнат                         10                     10
# Кристина                      10                     10
# Майя                          10                     10
# Максим                        10                     10
# Полина                         7                      0
# Ульяна                        10                      7
# Юлия                           0                     10
# Юрий                           7                      7
#
# название фильма  «Голодные игры» (2012)  «Стражи Галактики» (2014)  \
# Алексей                               6                          9
# Алена                                 5                          8
# Альбина                               7                          0
# Ангелина                             10                          7
# Андрей                               10                          0
# Анна                                  7                         10
# Артём                                 3                          5
# Валерия                               8                          7
# Всеволод                              7                          0
# Георгий                               5                          5
# Дмитрий                              10                         10
# Елизавета                            10                         10
# Игнат                                10                         10
# Кристина                              0                         10
# Майя                                 10                         10
# Максим                               10                         10
# Полина                               10                         10
# Ульяна                                8                         10
# Юлия                                  0                          0
# Юрий                                  8                         10
#
# название фильма  «Интерстеллар» (2014)  «Социальная сеть» (2010)  \
# Алексей                             10                         9
# Алена                               10                         0
# Альбина                             10                         0
# Ангелина                            10                         0
# Андрей                               6                         0
# Анна                                10                        10
# Артём                                5                         0
# Валерия                             10                         4
# Всеволод                            10                        10
# Георгий                             10                         0
# Дмитрий                             10                        10
# Елизавета                           10                        10
# Игнат                               10                        10
# Кристина                             0                         0
# Майя                                10                        10
# Максим                              10                         9
# Полина                              10                         0
# Ульяна                              10                         0
# Юлия                                10                         0
# Юрий                                10                         0
#
# название фильма  «Человек-паук: Через вселенные» (2018)  «Матрица» (1999)  \
# Алексей                                               7                10
# Алена                                                 0                10
# Альбина                                               8                 0
# Ангелина                                             10                10
# Андрей                                                0                 7
# Анна                                                 10                10
# Артём                                                 0                 9
# Валерия                                               3                10
# Всеволод                                              7                10
# Георгий                                               0                 8
# Дмитрий                                               7                 7
# Елизавета                                            10                10
# Игнат                                                 7                 7
# Кристина                                              0                10
# Майя                                                  7                 7
# Максим                                                0                 8
# Полина                                                0                 0
# Ульяна                                                8                10
# Юлия                                                  0                10
# Юрий                                                  8                10
#
# название фильма  «Матрица. Воскрешение» (2021)  \
# Алексей                                     10
# Алена                                        0
# Альбина                                      0
# Ангелина                                    10
# Андрей                                       0
# Анна                                         0
# Артём                                        9
# Валерия                                      8
# Всеволод                                     0
# Георгий                                      0
# Дмитрий                                      5
# Елизавета                                   10
# Игнат                                        5
# Кристина                                    10
# Майя                                         5
# Максим                                       8
# Полина                                       0
# Ульяна                                       9
# Юлия                                         9
# Юрий                                         9
#
# название фильма  «Матрица: Перезагрузка» (2003)  ...  «Субстанция»  \
# Алексей                                      10  ...             8
# Алена                                         0  ...             0
# Альбина                                       0  ...             0
# Ангелина                                     10  ...             5
# Андрей                                        0  ...             0
# Анна                                          0  ...             0
# Артём                                         9  ...             3
# Валерия                                       8  ...             8
# Всеволод                                      0  ...             8
# Георгий                                       0  ...             0
# Дмитрий                                       5  ...             1
# Елизавета                                    10  ...             0
# Игнат                                         5  ...             1
# Кристина                                     10  ...             0
# Майя                                          5  ...             0
# Максим                                        8  ...             0
# Полина                                        0  ...            10
# Ульяна                                        9  ...             5
# Юлия                                          8  ...             6
# Юрий                                          9  ...             5
#
# название фильма  «Фуриоса: Хроники Безумного Макса»  «Головоломка 2»  \
# Алексей                                           0               10
# Алена                                             0                0
# Альбина                                           0                0
# Ангелина                                          0                5
# Андрей                                            0               10
# Анна                                              0                0
# Артём                                            10               10
# Валерия                                           0                8
# Всеволод                                          0                0
# Георгий                                           0                0
# Дмитрий                                           0                0
# Елизавета                                         0               10
# Игнат                                             1                1
# Кристина                                         10               10
# Майя                                              0                0
# Максим                                            0                9
# Полина                                            0                8
# Ульяна                                            9                8
# Юлия                                              0               10
# Юрий                                              9                8
#
# название фильма  "Оппенгеймер" (2023)  "Брат 2"  "Темный рыцарь"  \
# Алексей                             8         9               10
# Алена                               0         8                0
# Альбина                             0         0                0
# Ангелина                            0         7                0
# Андрей                             10        10                0
# Анна                               10         7               10
# Артём                               9         9                0
# Валерия                             0        10                7
# Всеволод                           10        10               10
# Георгий                             0         0                0
# Дмитрий                             0         0               10
# Елизавета                          10        10                0
# Игнат                               1         1                1
# Кристина                           10         0               10
# Майя                                0         0                0
# Максим                             10         0                0
# Полина                             10         0               10
# Ульяна                             10        10                0
# Юлия                               10         0                9
# Юрий                               10        10                0
#
# название фильма  "Люди в черном"  Очень странные дела  Игра в кальмара  \
# Алексей                       10                    0                8
# Алена                          9                    0                7
# Альбина                        0                    0                0
# Ангелина                       7                    0                8
# Андрей                         7                    0                8
# Анна                          10                   10                9
# Артём                         10                   10                0
# Валерия                        9                    0                8
# Всеволод                      10                   10                0
# Георгий                        0                    6                0
# Дмитрий                       10                    0                8
# Елизавета                     10                    0                0
# Игнат                          1                    1                1
# Кристина                      10                   10               10
# Майя                           0                   10               10
# Максим                         0                   10                0
# Полина                         0                   10                7
# Ульяна                        10                    7                8
# Юлия                           0                   10                0
# Юрий                          10                    7                8
#
# название фильма  Черное зеркало
# Алексей                       0
# Алена                         0
# Альбина                       0
# Ангелина                      0
# Андрей                        0
# Анна                         10
# Артём                         0
# Валерия                       0
# Всеволод                     10
# Георгий                       6
# Дмитрий                       0
# Елизавета                    10
# Игнат                         1
# Кристина                     10
# Майя                          0
# Максим                        0
# Полина                        8
# Ульяна                        0
# Юлия                          8
# Юрий                          0
#
# [20 rows x 64 columns]

# %%
# воспользуемся классом NearestNeighbors для поиска расстояний
knn = NearestNeighbors(metric = 'cosine',
                       algorithm = 'brute',
                       n_neighbors = 20,
                       n_jobs = -1)

# обучим модель
knn.fit(filtered_matrix1)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1, n_neighbors=20)

# %%
# определимся, сколько рекомендаций мы хотим получить
recommendations = 5

# и для какого зрителя
search_word = 'Ангелина'

# %%
# теперь нужно найти индексы и расстояния
# воспользуемся методом kneighbors()
distances, indices = knn.kneighbors(filtered_matrix1.loc[[search_word]], n_neighbors = recommendations + 1)

# Обрабатываем результаты
similar_movies = filtered_matrix1.index[indices.flatten()[1:]]  # Исключаем субъекта рекомендаций
distances = distances.flatten()[1:]

# Создаем DataFrame с результатами
results = pd.DataFrame({
    'Зритель': similar_movies,
    'Расстояние': distances
})
# Добавляем рейтинг (1 - самый близкий)
results['Рейтинг похожести'] = range(1, len(results)+1)

# Сортируем по расстоянию (на всякий случай)
results = results.sort_values('Расстояние')

print(f"Топ-{recommendations} зрителей с интересами, похожими на '{search_word}':\n")
print(results[['Рейтинг похожести', 'Зритель', 'Расстояние']].to_string(index=False))
# Out:
# Топ-5 зрителей с интересами, похожими на 'Ангелина':
#
#  Рейтинг похожести Зритель  Расстояние
#                  1  Ульяна    0.203167
#                  2    Юрий    0.206692
#                  3 Алексей    0.207711
#                  4   Игнат    0.226924
#                  5 Валерия    0.231438

# %% [markdown]
# Получилось, что для пользователя Ангелина самый близкий - Ульяна. Посмотрим фильмы для него.

# %%
user_item_matrix = pd.read_excel('ratingNames.xlsx')
user_item_matrix
# Out:
#               название фильма  Алексей  Алена  Алина  Альбина  Анастасия  \
# 0             «Дэдпул» (2016)        8      7      0        0          0
# 1       «Бумажный дом» (2019)        7      0      0        0          0
# 2      «Голодные игры» (2012)        6      5      0        7          0
# 3   «Стражи Галактики» (2014)        9      8      0        0          0
# 4       «Интерстеллар» (2014)       10     10      0       10          0
# ..                        ...      ...    ...    ...      ...        ...
# 88                Харли Квинн        0      0      0        0          0
# 89               Слабый герой        0      0      0        0          0
# 90                  Мошенники        0      0      0        0          0
# 91                    Укрытие        0      0      0        0          0
# 92               Дети перемен        0      0      0        0          0
#
#     Ангелина  Андрей  Анна  Арина  ...  Кристина  Майя  Максим  Надежда  \
# 0         10       0     8      0  ...        10    10      10        0
# 1         10      10    10      0  ...        10    10      10        0
# 2         10      10     7      0  ...         0    10      10        0
# 3          7       0    10      0  ...        10    10      10        0
# 4         10       6    10      0  ...         0    10      10        0
# ..       ...     ...   ...    ...  ...       ...   ...     ...      ...
# 88         0       0     0      0  ...         0     0       0        0
# 89         0       0     0      0  ...        10     0       0        0
# 90         0       0     0      0  ...        10     0       0        0
# 91         0       0     0      0  ...        10     0       0        0
# 92         0       0     0      0  ...        10     0       0        0
#
#     Полина  Самира  София  Ульяна  Юлия  Юрий
# 0        7       0      0      10     0     7
# 1        0       0      0       7    10     7
# 2       10       0      0       8     0     8
# 3       10       0      0      10     0    10
# 4       10       0      0      10    10    10
# ..     ...     ...    ...     ...   ...   ...
# 88       0       0      0       8     0     8
# 89       0       0      0       0     0     0
# 90       0       0      0       0     0     0
# 91       0       0      0       0     0     0
# 92       0       0      0       0     0     0
#
# [93 rows x 31 columns]

# %%
# находим топ-5 фильмов для Ульяны с оценками этих фильмов
search_word = 'Ульяна'

# %%
a = user_item_matrix.nlargest(5, search_word)[['название фильма', search_word]]
a
# Out:
#               название фильма  Ульяна
# 0             «Дэдпул» (2016)      10
# 3   «Стражи Галактики» (2014)      10
# 4       «Интерстеллар» (2014)      10
# 7            «Матрица» (1999)      10
# 16          «Аватар 2» (2022)      10

# %%
# находим топ-5 фильмов для Ангелины с оценками этих фильмов
search_word = 'Ангелина'

# %%
a = user_item_matrix.nlargest(5, search_word)[['название фильма', search_word]]
a
# Out:
#                           название фильма  Ангелина
# 0                         «Дэдпул» (2016)        10
# 1                   «Бумажный дом» (2019)        10
# 2                  «Голодные игры» (2012)        10
# 4                   «Интерстеллар» (2014)        10
# 6  «Человек-паук: Через вселенные» (2018)        10

# %% [markdown]
# В пересечении тоже Интерстеллар,  «Дэдпул» (2016) в фильмах топ-5.

# %% [markdown]
# ## <a class="anchor" id="2"><div class="alert alert-block alert-success">Вопрос 2: отличается ли средний рейтинг фильмов у пользователей Игнат и похожего на него?

# %%
user_item_matrix = user_item_matrix.set_index('название фильма')
user_item_matrix
# Out:
#                            Алексей  Алена  Алина  Альбина  Анастасия  \
# название фильма
# «Дэдпул» (2016)                  8      7      0        0          0
# «Бумажный дом» (2019)            7      0      0        0          0
# «Голодные игры» (2012)           6      5      0        7          0
# «Стражи Галактики» (2014)        9      8      0        0          0
# «Интерстеллар» (2014)           10     10      0       10          0
# ...                            ...    ...    ...      ...        ...
# Харли Квинн                      0      0      0        0          0
# Слабый герой                     0      0      0        0          0
# Мошенники                        0      0      0        0          0
# Укрытие                          0      0      0        0          0
# Дети перемен                     0      0      0        0          0
#
#                            Ангелина  Андрей  Анна  Арина  Артём  ...  \
# название фильма                                                  ...
# «Дэдпул» (2016)                  10       0     8      0      6  ...
# «Бумажный дом» (2019)            10      10    10      0      8  ...
# «Голодные игры» (2012)           10      10     7      0      3  ...
# «Стражи Галактики» (2014)         7       0    10      0      5  ...
# «Интерстеллар» (2014)            10       6    10      0      5  ...
# ...                             ...     ...   ...    ...    ...  ...
# Харли Квинн                       0       0     0      0      0  ...
# Слабый герой                      0       0     0      0      0  ...
# Мошенники                         0       0     0      0      9  ...
# Укрытие                           0       0     0      0      0  ...
# Дети перемен                      0       0     0      0      0  ...
#
#                            Кристина  Майя  Максим  Надежда  Полина  Самира  \
# название фильма
# «Дэдпул» (2016)                  10    10      10        0       7       0
# «Бумажный дом» (2019)            10    10      10        0       0       0
# «Голодные игры» (2012)            0    10      10        0      10       0
# «Стражи Галактики» (2014)        10    10      10        0      10       0
# «Интерстеллар» (2014)             0    10      10        0      10       0
# ...                             ...   ...     ...      ...     ...     ...
# Харли Квинн                       0     0       0        0       0       0
# Слабый герой                     10     0       0        0       0       0
# Мошенники                        10     0       0        0       0       0
# Укрытие                          10     0       0        0       0       0
# Дети перемен                     10     0       0        0       0       0
#
#                            София  Ульяна  Юлия  Юрий
# название фильма
# «Дэдпул» (2016)                0      10     0     7
# «Бумажный дом» (2019)          0       7    10     7
# «Голодные игры» (2012)         0       8     0     8
# «Стражи Галактики» (2014)      0      10     0    10
# «Интерстеллар» (2014)          0      10    10    10
# ...                          ...     ...   ...   ...
# Харли Квинн                    0       8     0     8
# Слабый герой                   0       0     0     0
# Мошенники                      0       0     0     0
# Укрытие                        0       0     0     0
# Дети перемен                   0       0     0     0
#
# [93 rows x 30 columns]

# %%
filtered_matrix1 = user_item_matrix.T
filtered_matrix1
# Out:
# название фильма  «Дэдпул» (2016)  «Бумажный дом» (2019)  \
# Алексей                        8                      7
# Алена                          7                      0
# Алина                          0                      0
# Альбина                        0                      0
# Анастасия                      0                      0
# Ангелина                      10                     10
# Андрей                         0                     10
# Анна                           8                     10
# Арина                          0                      0
# Артём                          6                      8
# Валерия                        8                      7
# Виктория                       0                      0
# Всеволод                       0                      0
# Георгий                        0                      0
# Дарья                          0                      0
# Дмитрий                       10                     10
# Екатерина                      0                      0
# Елизавета                     10                     10
# Игнат                         10                     10
# Ирина                          0                     10
# Кристина                      10                     10
# Майя                          10                     10
# Максим                        10                     10
# Надежда                        0                      0
# Полина                         7                      0
# Самира                         0                      0
# София                          0                      0
# Ульяна                        10                      7
# Юлия                           0                     10
# Юрий                           7                      7
#
# название фильма  «Голодные игры» (2012)  «Стражи Галактики» (2014)  \
# Алексей                               6                          9
# Алена                                 5                          8
# Алина                                 0                          0
# Альбина                               7                          0
# Анастасия                             0                          0
# Ангелина                             10                          7
# Андрей                               10                          0
# Анна                                  7                         10
# Арина                                 0                          0
# Артём                                 3                          5
# Валерия                               8                          7
# Виктория                              0                          0
# Всеволод                              7                          0
# Георгий                               5                          5
# Дарья                                 0                          0
# Дмитрий                              10                         10
# Екатерина                             0                          0
# Елизавета                            10                         10
# Игнат                                10                         10
# Ирина                                10                          0
# Кристина                              0                         10
# Майя                                 10                         10
# Максим                               10                         10
# Надежда                               0                          0
# Полина                               10                         10
# Самира                                0                          0
# София                                 0                          0
# Ульяна                                8                         10
# Юлия                                  0                          0
# Юрий                                  8                         10
#
# название фильма  «Интерстеллар» (2014)  «Социальная сеть» (2010)  \
# Алексей                             10                         9
# Алена                               10                         0
# Алина                                0                         0
# Альбина                             10                         0
# Анастасия                            0                         0
# Ангелина                            10                         0
# Андрей                               6                         0
# Анна                                10                        10
# Арина                                0                         0
# Артём                                5                         0
# Валерия                             10                         4
# Виктория                             0                         0
# Всеволод                            10                        10
# Георгий                             10                         0
# Дарья                                0                         0
# Дмитрий                             10                        10
# Екатерина                            0                         0
# Елизавета                           10                        10
# Игнат                               10                        10
# Ирина                                0                         0
# Кристина                             0                         0
# Майя                                10                        10
# Максим                              10                         9
# Надежда                              0                         0
# Полина                              10                         0
# Самира                               0                         0
# София                                0                         0
# Ульяна                              10                         0
# Юлия                                10                         0
# Юрий                                10                         0
#
# название фильма  «Человек-паук: Через вселенные» (2018)  «Матрица» (1999)  \
# Алексей                                               7                10
# Алена                                                 0                10
# Алина                                                 0                 0
# Альбина                                               8                 0
# Анастасия                                             0                 0
# Ангелина                                             10                10
# Андрей                                                0                 7
# Анна                                                 10                10
# Арина                                                 0                 0
# Артём                                                 0                 9
# Валерия                                               3                10
# Виктория                                              0                 0
# Всеволод                                              7                10
# Георгий                                               0                 8
# Дарья                                                 0                 0
# Дмитрий                                               7                 7
# Екатерина                                             0                 0
# Елизавета                                            10                10
# Игнат                                                 7                 7
# Ирина                                                 0                 0
# Кристина                                              0                10
# Майя                                                  7                 7
# Максим                                                0                 8
# Надежда                                               0                 0
# Полина                                                0                 0
# Самира                                                0                 0
# София                                                 0                 0
# Ульяна                                                8                10
# Юлия                                                  0                10
# Юрий                                                  8                10
#
# название фильма  «Матрица. Воскрешение» (2021)  \
# Алексей                                     10
# Алена                                        0
# Алина                                        0
# Альбина                                      0
# Анастасия                                    0
# Ангелина                                    10
# Андрей                                       0
# Анна                                         0
# Арина                                        0
# Артём                                        9
# Валерия                                      8
# Виктория                                     0
# Всеволод                                     0
# Георгий                                      0
# Дарья                                        0
# Дмитрий                                      5
# Екатерина                                    0
# Елизавета                                   10
# Игнат                                        5
# Ирина                                        0
# Кристина                                    10
# Майя                                         5
# Максим                                       8
# Надежда                                      0
# Полина                                       0
# Самира                                       0
# София                                        0
# Ульяна                                       9
# Юлия                                         9
# Юрий                                         9
#
# название фильма  «Матрица: Перезагрузка» (2003)  ...  Игра в кальмара  \
# Алексей                                      10  ...                8
# Алена                                         0  ...                7
# Алина                                         0  ...                0
# Альбина                                       0  ...                0
# Анастасия                                     0  ...                0
# Ангелина                                     10  ...                8
# Андрей                                        0  ...                8
# Анна                                          0  ...                9
# Арина                                         0  ...                0
# Артём                                         9  ...                0
# Валерия                                       8  ...                8
# Виктория                                      0  ...                0
# Всеволод                                      0  ...                0
# Георгий                                       0  ...                0
# Дарья                                         0  ...                0
# Дмитрий                                       5  ...                8
# Екатерина                                     0  ...                0
# Елизавета                                    10  ...                0
# Игнат                                         5  ...                1
# Ирина                                         0  ...                0
# Кристина                                     10  ...               10
# Майя                                          5  ...               10
# Максим                                        8  ...                0
# Надежда                                       0  ...                0
# Полина                                        0  ...                7
# Самира                                        0  ...                0
# София                                         0  ...                0
# Ульяна                                        9  ...                8
# Юлия                                          8  ...                0
# Юрий                                          9  ...                8
#
# название фильма  Черное зеркало  Злой город  Одни из нас  \
# Алексей                       0           0            0
# Алена                         0           0            0
# Алина                         0           0            0
# Альбина                       0           0            0
# Анастасия                     0           0            0
# Ангелина                      0           0            0
# Андрей                        0           0            0
# Анна                         10           0            0
# Арина                         0           0            0
# Артём                         0           0            0
# Валерия                       0           0            0
# Виктория                      0           0            0
# Всеволод                     10           0            0
# Георгий                       6           0            0
# Дарья                         0           0            0
# Дмитрий                       0           0            8
# Екатерина                     0           0            0
# Елизавета                    10           0            0
# Игнат                         1           1            1
# Ирина                         0           0            0
# Кристина                     10          10            0
# Майя                          0           0            0
# Максим                        0           0            0
# Надежда                       0           0            0
# Полина                        8           0            6
# Самира                        0           0            0
# София                         0           0            0
# Ульяна                        0           0            0
# Юлия                          8           0            0
# Юрий                          0           0            0
#
# название фильма  Формула преступления  Харли Квинн  Слабый герой  Мошенники  \
# Алексей                             0            0             0          0
# Алена                               0            0             0          0
# Алина                               0            0             0          0
# Альбина                             0            0             0          0
# Анастасия                           0            0             0          0
# Ангелина                            0            0             0          0
# Андрей                              0            0             0          0
# Анна                                0            0             0          0
# Арина                               0            0             0          0
# Артём                               0            0             0          9
# Валерия                             0            0             0          0
# Виктория                            0            0             0          0
# Всеволод                            0            0             0          0
# Георгий                             0            0             0          0
# Дарья                               0            0             0          0
# Дмитрий                             0            0             0          0
# Екатерина                           0            0             0          0
# Елизавета                           0            0             0          0
# Игнат                               1            1             1          1
# Ирина                               0            0             0          0
# Кристина                           10            0            10         10
# Майя                                0            0             0          0
# Максим                              0            0             0          0
# Надежда                             0            0             0          0
# Полина                              0            0             0          0
# Самира                              0            0             0          0
# София                               0            0             0          0
# Ульяна                              8            8             0          0
# Юлия                                0            0             0          0
# Юрий                                8            8             0          0
#
# название фильма  Укрытие  Дети перемен
# Алексей                0             0
# Алена                  0             0
# Алина                  0             0
# Альбина                0             0
# Анастасия              0             0
# Ангелина               0             0
# Андрей                 0             0
# Анна                   0             0
# Арина                  0             0
# Артём                  0             0
# Валерия                0             0
# Виктория               0             0
# Всеволод               0             0
# Георгий                0             0
# Дарья                  0             0
# Дмитрий                0             0
# Екатерина              0             0
# Елизавета              0             0
# Игнат                  1             1
# Ирина                  0             0
# Кристина              10            10
# Майя                   0             0
# Максим                 0             0
# Надежда                0             0
# Полина                 0             0
# Самира                 0             0
# София                  0             0
# Ульяна                 0             0
# Юлия                   0             0
# Юрий                   0             0
#
# [30 rows x 93 columns]

# %%
# воспользуемся классом NearestNeighbors для поиска расстояний
knn = NearestNeighbors(metric = 'cosine',
                       algorithm = 'brute',
                       n_neighbors = 20,
                       n_jobs = -1)

# обучим модель
knn.fit(filtered_matrix1)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1, n_neighbors=20)

# %%
# определимся, сколько рекомендаций мы хотим получить
recommendations = 5

# и для какого зрителя
search_word = 'Игнат'

# %%
# теперь нужно найти индексы и расстояния
# воспользуемся методом kneighbors()
distances, indices = knn.kneighbors(filtered_matrix1.loc[[search_word]], n_neighbors = recommendations + 1)

# Обрабатываем результаты
similar_movies = filtered_matrix1.index[indices.flatten()[1:]]  # Исключаем субъекта рекомендаций
distances = distances.flatten()[1:]

# Создаем DataFrame с результатами
results = pd.DataFrame({
    'Зритель': similar_movies,
    'Расстояние': distances
})
# Добавляем рейтинг (1 - самый близкий)
results['Рейтинг похожести'] = range(1, len(results)+1)

# Сортируем по расстоянию (на всякий случай)
results = results.sort_values('Расстояние')

print(f"Топ-{recommendations} зрителей с интересами, похожими на '{search_word}':\n")
print(results[['Рейтинг похожести', 'Зритель', 'Расстояние']].to_string(index=False))
# Out:
# Топ-5 зрителей с интересами, похожими на 'Игнат':
#
#  Рейтинг похожести  Зритель  Расстояние
#                  1     Майя    0.046095
#                  2  Дмитрий    0.075094
#                  3   Ульяна    0.230282
#                  4 Ангелина    0.233530
#                  5     Юрий    0.233748

# %% [markdown]
# Майя и Игнат близки по интересам, посмотрим их средний рейтинг фильмов

# %%
user_ratings = user_item_matrix['Игнат']
print(f"  • Средний рейтинг Игната: {user_ratings.mean():.1f}")
# Out:
#   • Средний рейтинг Игната: 3.2

# %%
user_ratings = user_item_matrix['Майя']
print(f"  • Средний рейтинг Майи: {user_ratings.mean():.1f}")
# Out:
#   • Средний рейтинг Майи: 3.1

# %% [markdown]
# В итоге их средние рейтинги очень близки, отличаются на 0.1.

# %% [markdown]
# ## <a class="anchor" id="2"><div class="alert alert-block alert-success">Вопрос 3: отличается ли количество оценок у пользователей Юлия и похожего на него?

# %%
# воспользуемся классом NearestNeighbors для поиска расстояний
knn = NearestNeighbors(metric = 'cosine',
                       algorithm = 'brute',
                       n_neighbors = 20,
                       n_jobs = -1)

# обучим модель
knn.fit(filtered_matrix1)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1, n_neighbors=20)

# %%
# определимся, сколько рекомендаций мы хотим получить
recommendations = 5

# и для какого зрителя
search_word = 'Юлия'

# %%
# теперь нужно найти индексы и расстояния
# воспользуемся методом kneighbors()
distances, indices = knn.kneighbors(filtered_matrix1.loc[[search_word]], n_neighbors = recommendations + 1)

# Обрабатываем результаты
similar_movies = filtered_matrix1.index[indices.flatten()[1:]]  # Исключаем субъекта рекомендаций
distances = distances.flatten()[1:]

# Создаем DataFrame с результатами
results = pd.DataFrame({
    'Зритель': similar_movies,
    'Расстояние': distances
})
# Добавляем рейтинг (1 - самый близкий)
results['Рейтинг похожести'] = range(1, len(results)+1)

# Сортируем по расстоянию (на всякий случай)
results = results.sort_values('Расстояние')

print(f"Топ-{recommendations} зрителей с интересами, похожими на '{search_word}':\n")
print(results[['Рейтинг похожести', 'Зритель', 'Расстояние']].to_string(index=False))
# Out:
# Топ-5 зрителей с интересами, похожими на 'Юлия':
#
#  Рейтинг похожести Зритель  Расстояние
#                  1  Полина    0.363025
#                  2 Алексей    0.365190
#                  3    Юрий    0.375473
#                  4  Ульяна    0.382730
#                  5   Артём    0.388475

# %% [markdown]
# Юлия и Полина близки по интересам, посмотрим их средний рейтинг фильмов

# %%
user_ratings = user_item_matrix['Игнат']
print(f"  • Оценила фильмов Юлия: {len(user_ratings)}")
# Out:
#   • Оценила фильмов Юлия: 93

# %%
user_ratings = user_item_matrix['Полина']
print(f"  • Оценила фильмов Полина: {len(user_ratings)}")
# Out:
#   • Оценил фильмов Полина: 93

# %% [markdown]
# Они оценили одинаковое количество фильмов.

# %% [markdown]
# ## <a class="anchor" id="2"><div class="alert alert-block alert-success">Вопрос 4: отличается ли средний рейтинг фильма «Дэдпул» (2016) и самого похожего на него?

# %%
filtered_matrix = user_item_matrix

# %%
# воспользуемся классом NearestNeighbors для поиска расстояний
knn = NearestNeighbors(metric = 'cosine',
                       algorithm = 'brute',
                       n_neighbors = 5,
                       n_jobs = -1)

# обучим модель
knn.fit(filtered_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1)

# %%
# определимся, сколько рекомендаций мы хотим получить
recommendations = 5

# и на основе какого фильма
search_word = '«Дэдпул» (2016)'

# %%
# теперь нужно найти индексы и расстояния фильмов, которые похожи на наш запрос
# воспользуемся методом kneighbors()
distances, indices = knn.kneighbors(filtered_matrix.loc[[search_word]], n_neighbors = recommendations + 1)

# %%
indices
# Out:
# array([[ 0,  3, 36, 10,  9, 22]], dtype=int64)

# %%
distances
# Out:
# array([[0.        , 0.02319406, 0.10012523, 0.14147297, 0.1480065 ,
#         0.15033642]])

# %%
# Обрабатываем результаты
similar_movies = filtered_matrix.index[indices.flatten()[1:]]  # Исключаем исходный фильм
distances = distances.flatten()[1:]

# Создаем DataFrame с результатами
results = pd.DataFrame({
    'Фильм': similar_movies,
    'Расстояние': distances
})
# Добавляем рейтинг (1 - самый близкий)
results['Рейтинг похожести'] = range(1, len(results)+1)

# Сортируем по расстоянию (на всякий случай)
results = results.sort_values('Расстояние')

print(f"Топ-{recommendations} похожих фильмов на '{search_word}':\n")
print(results[['Рейтинг похожести', 'Фильм', 'Расстояние']].to_string(index=False))
# Out:
# Топ-5 похожих фильмов на '«Дэдпул» (2016)':
#
#  Рейтинг похожести                              Фильм  Расстояние
#                  1          «Стражи Галактики» (2014)    0.023194
#                  2 «Стражи Галактики. Часть 2» (2017)    0.100125
#                  3        «Матрица: Революция» (2003)    0.141473
#                  4     «Матрица: Перезагрузка» (2003)    0.148007
#                  5                    «Форсаж» (2001)    0.150336

# %%
# загрузим данные
user_item_matrix = pd.read_excel('ratingNames.xlsx')
user_item_matrix
# Out:
#               название фильма  Алексей  Алена  Алина  Альбина  Анастасия  \
# 0             «Дэдпул» (2016)        8      7      0        0          0
# 1       «Бумажный дом» (2019)        7      0      0        0          0
# 2      «Голодные игры» (2012)        6      5      0        7          0
# 3   «Стражи Галактики» (2014)        9      8      0        0          0
# 4       «Интерстеллар» (2014)       10     10      0       10          0
# ..                        ...      ...    ...    ...      ...        ...
# 88                Харли Квинн        0      0      0        0          0
# 89               Слабый герой        0      0      0        0          0
# 90                  Мошенники        0      0      0        0          0
# 91                    Укрытие        0      0      0        0          0
# 92               Дети перемен        0      0      0        0          0
#
#     Ангелина  Андрей  Анна  Арина  ...  Кристина  Майя  Максим  Надежда  \
# 0         10       0     8      0  ...        10    10      10        0
# 1         10      10    10      0  ...        10    10      10        0
# 2         10      10     7      0  ...         0    10      10        0
# 3          7       0    10      0  ...        10    10      10        0
# 4         10       6    10      0  ...         0    10      10        0
# ..       ...     ...   ...    ...  ...       ...   ...     ...      ...
# 88         0       0     0      0  ...         0     0       0        0
# 89         0       0     0      0  ...        10     0       0        0
# 90         0       0     0      0  ...        10     0       0        0
# 91         0       0     0      0  ...        10     0       0        0
# 92         0       0     0      0  ...        10     0       0        0
#
#     Полина  Самира  София  Ульяна  Юлия  Юрий
# 0        7       0      0      10     0     7
# 1        0       0      0       7    10     7
# 2       10       0      0       8     0     8
# 3       10       0      0      10     0    10
# 4       10       0      0      10    10    10
# ..     ...     ...    ...     ...   ...   ...
# 88       0       0      0       8     0     8
# 89       0       0      0       0     0     0
# 90       0       0      0       0     0     0
# 91       0       0      0       0     0     0
# 92       0       0      0       0     0     0
#
# [93 rows x 31 columns]

# %%
film = '«Дэдпул» (2016)'
ratings = user_item_matrix.loc[user_item_matrix['название фильма'] == film, users].values[0]
non_zero_ratings = ratings
non_zero_ratings.mean().round(1)
# Out:
# 6.6

# %%
film = '«Стражи Галактики» (2014)'
ratings = user_item_matrix.loc[user_item_matrix['название фильма'] == film, users].values[0]
non_zero_ratings = ratings
non_zero_ratings.mean().round(1)
# Out:
# 7.0

# %% [markdown]
# У второго фильма оценка получилась даже больше, чем у первого.

# %% [markdown]
# ## <a class="anchor" id="2"><div class="alert alert-block alert-success">Вопрос 5: отличается ли количество оценок фильма Укрытие и самого похожего на него?

# %%
filtered_matrix = user_item_matrix.set_index('название фильма')

# %%
# воспользуемся классом NearestNeighbors для поиска расстояний
knn = NearestNeighbors(metric = 'cosine',
                       algorithm = 'brute',
                       n_neighbors = 5,
                       n_jobs = -1)

# обучим модель
knn.fit(filtered_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1)

# %%
# определимся, сколько рекомендаций мы хотим получить
recommendations = 5

# и на основе какого фильма
search_word = 'Укрытие'

# %%
# теперь нужно найти индексы и расстояния фильмов, которые похожи на наш запрос
# воспользуемся методом kneighbors()
distances, indices = knn.kneighbors(filtered_matrix.loc[[search_word]], n_neighbors = recommendations + 1)

# %%
indices
# Out:
# array([[89, 91, 85, 92, 60, 57]], dtype=int64)

# %%
distances
# Out:
# array([[0.        , 0.        , 0.        , 0.        , 0.00496281,
#         0.00990099]])

# %%
# Обрабатываем результаты
similar_movies = filtered_matrix.index[indices.flatten()[1:]]  # Исключаем исходный фильм
distances = distances.flatten()[1:]

# Создаем DataFrame с результатами
results = pd.DataFrame({
    'Фильм': similar_movies,
    'Расстояние': distances
})
# Добавляем рейтинг (1 - самый близкий)
results['Рейтинг похожести'] = range(1, len(results)+1)

# Сортируем по расстоянию (на всякий случай)
results = results.sort_values('Расстояние')

print(f"Топ-{recommendations} похожих фильмов на '{search_word}':\n")
print(results[['Рейтинг похожести', 'Фильм', 'Расстояние']].to_string(index=False))
# Out:
# Топ-5 похожих фильмов на 'Укрытие':
#
#  Рейтинг похожести                         Фильм  Расстояние
#                  1                       Укрытие    0.000000
#                  2                    Злой город    0.000000
#                  3                  Дети перемен    0.000000
#                  4             «Ячейка общества»    0.004963
#                  5 «Надо снимать фильмы о любви»    0.009901

# %%
# загрузим данные
user_item_matrix = pd.read_excel('ratingNames.xlsx')
user_item_matrix
# Out:
#               название фильма  Алексей  Алена  Алина  Альбина  Анастасия  \
# 0             «Дэдпул» (2016)        8      7      0        0          0
# 1       «Бумажный дом» (2019)        7      0      0        0          0
# 2      «Голодные игры» (2012)        6      5      0        7          0
# 3   «Стражи Галактики» (2014)        9      8      0        0          0
# 4       «Интерстеллар» (2014)       10     10      0       10          0
# ..                        ...      ...    ...    ...      ...        ...
# 88                Харли Квинн        0      0      0        0          0
# 89               Слабый герой        0      0      0        0          0
# 90                  Мошенники        0      0      0        0          0
# 91                    Укрытие        0      0      0        0          0
# 92               Дети перемен        0      0      0        0          0
#
#     Ангелина  Андрей  Анна  Арина  ...  Кристина  Майя  Максим  Надежда  \
# 0         10       0     8      0  ...        10    10      10        0
# 1         10      10    10      0  ...        10    10      10        0
# 2         10      10     7      0  ...         0    10      10        0
# 3          7       0    10      0  ...        10    10      10        0
# 4         10       6    10      0  ...         0    10      10        0
# ..       ...     ...   ...    ...  ...       ...   ...     ...      ...
# 88         0       0     0      0  ...         0     0       0        0
# 89         0       0     0      0  ...        10     0       0        0
# 90         0       0     0      0  ...        10     0       0        0
# 91         0       0     0      0  ...        10     0       0        0
# 92         0       0     0      0  ...        10     0       0        0
#
#     Полина  Самира  София  Ульяна  Юлия  Юрий
# 0        7       0      0      10     0     7
# 1        0       0      0       7    10     7
# 2       10       0      0       8     0     8
# 3       10       0      0      10     0    10
# 4       10       0      0      10    10    10
# ..     ...     ...    ...     ...   ...   ...
# 88       0       0      0       8     0     8
# 89       0       0      0       0     0     0
# 90       0       0      0       0     0     0
# 91       0       0      0       0     0     0
# 92       0       0      0       0     0     0
#
# [93 rows x 31 columns]

# %%
film = 'Укрытие'
ratings = user_item_matrix.loc[user_item_matrix['название фильма'] == film, users].values[0]
non_zero_ratings = ratings
len(non_zero_ratings)
# Out:
# 20

# %%
film = 'Злой город'
ratings = user_item_matrix.loc[user_item_matrix['название фильма'] == film, users].values[0]
non_zero_ratings = ratings
len(non_zero_ratings)
# Out:
# 20

# %% [markdown]
# У этих фильмов одинаковое количество оценок.
